# %% [markdown]
# # Module 2 Challenge Question: Summation of Primes

# %% [markdown]
# The sum of primes below 10 is 2 + 3 + 5 + 7 = 17. Please write a Python program to find the sum of all the primes below 5000.

# %% [markdown]
# ## Answer:

# %%
# Answer:
