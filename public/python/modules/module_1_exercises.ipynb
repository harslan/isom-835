# %% [markdown]
# # Module 1 Exercises

# %% [markdown]
# ## Question 1

# %%
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# Note: We won’t worry about making sure our pay has exactly two digits after the decimal place for now. 
# If you want, you can play with the built-in Python round function to properly round the 
# resulting pay to two decimal places.

# %%
# Answer:
hours = input("Enter number of hours: ")
pay = input("Enter pay per hour:")
hours = float(hours)
pay = float(pay)
total = hours * pay
print("total pay is", total)

# %% [markdown]
# ## Question 2

# %%
# Write a program which prompts the user for a Celsius temperature, 
# convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
# Answer:
celc_temp = input("Enter the temprature in celcius:")
celc_temp = float(celc_temp)
fah_temp = 32 + celc_temp*1.8
print(fah_temp)

# %% [markdown]
# ## Question 3

# %%
# Write a program to prompt for a score between 0.0 and 1.0. 
# If the score is out of range, print an error message. If the score 
# is between 0.0 and 1.0, 
# print a grade using the following table:
#
# Score   Grade
# >= 0.9    A
# >= 0.8    B
# >= 0.7    C
# >= 0.6    D
# <0.6      F

# Enter score: 0.95
# A

# Enter score: perfect
# Bad score

# Enter score: 10.0
# Bad score

# Enter score: 0.75
# C

# Enter score: 0.5
# F
#
# Run the program repeatedly as shown above to test the various different values for input.

# %%
# Answer:
grade = input("Please enter a score between 0 and 1:")
grade = float(grade)
if grade >= 0 and grade <=1:
  print("valid input")
  if grade >= 0.9:
    print("grade is A")
  elif grade >= 0.8:
    print("grade is B")
  elif grade >= 0.7:
    print("grade is C")
  elif grade >=0.6:
    print("grade is D")
  else:
    print('grade is F')
else:
  print("invalid input")

# %% [markdown]
# ## Question 4

# %%
# Rewrite your pay computation to give the employee 1.5 times the hourly rate for hours worked 
# above 40 hours.
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
 #Answer:
hours = input("Enter number of hours: ")
pay = input("Enter pay per hour:")
hours = float(hours)
pay = float(pay)
if hours <=40:
  total = hours * pay
else:
  total = (hours-40)*1.5*pay + 40*pay
print("total pay is", total)

# %% [markdown]
# ## Question 5

# %%
# Rewrite your pay computation with time-and-a-half for overtime 
# and create a function called computepay which takes two parameters (hours and rate).
#
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
# Answer:
def compute_pay():
  hours = input("Enter number of hours: ")
  pay = input("Enter pay per hour:")
  hours = float(hours)
  pay = float(pay)
  if hours <=40:
    total = hours * pay
  else:
    total = (hours-40)*1.5*pay + 40*pay
  print("total pay is", total)

compute_pay()

# %%
# room area calculation
def size_of_a_room(side1, side2):
  area = side1*side2
  print(area)

# %%
size_of_a_room(10,20)

# %%
size_of_a_room(25,20)

# %% [markdown]
# ## Question 6

# %%
# Rewrite the grade program from the previous exercise using a function 
# called computegrade that takes a score as its parameter and returns a grade as a string.

# Score
# >= 0.9     A
# >= 0.8     B
# >= 0.7     C
# >= 0.6     D
# <0.6       F


# Enter score: 0.95
# A

# Enter score: perfect
# Bad score

# Enter score: 10.0
# Bad score

# Enter score: 0.75
# C

# Enter score: 0.5
# F

# Run the program repeatedly to test the various different values for input.

# %%
# Answer
user_input = input("Enter a score")
try:
  num_input = float(user_input)
  if num_input <=1 and num_input >= 0:
    print("a valid range")
    if num_input >= 0.9:
      print("A")
    elif num_input >= 0.8:
      print("B")
  else:
    print("enter a valid range")

except:
  print("enter a numerical value")

# %% [markdown]
# ## Question 7

# %%
# Write a program which repeatedly reads numbers until the user 
# enters “done”. Once “done” is entered, print out the total, count, and average of the numbers. 
# If the user enters anything other than a number, detect their mistake using try and except 
# and print an error message and skip to the next number.

# A sample run would be:

# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333


# 1. We need a script to run until a certain criteria is met, i.e., "done" is entered by the user (While loop)
# 2. We need an if statement to check if the criteria is met

total = 0
count = 0
while True:
  # collect input from the user and store into a variable called user_input
  user_input = input("Enter a number, please:")

  # check if the user_input is "done"; if so, stop the loop.
  if user_input == 'done' or user_input ==  "Done":
    break

  try:
    user_number = int(user_input) # if this conversion fails, that means the user did not enter an integer

  except: 
    print("Warning: Invalid Input, please enter an integer!")
    continue
  
  total = total + user_number
  count = count + 1

print("the loop is done and exited.")

print("Total:", total)
print("Count:", count)

if count > 0:
  print("Average", total/count)
else:
  print("user did not enter any integers")

# %%
type("4")

# %%
type('4')

# %%
type(int('4'))

# %%
# Answer:
bucket = 0
count = 0
while True:
  num = input("Enter a number: ")
  if num == "done":
    break
  try:
    num = int(num)
    bucket = bucket + num
    count = count + 1
  except:
    print("invalid input")
print("Done!")
print("The sum is", bucket)
print("Total numbers are", count)
