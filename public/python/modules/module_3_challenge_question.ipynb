# %% [markdown]
# # Module 3 Challenge Question: FizzBuzz

# %% [markdown]
# Write a Python program that prints all of the numbers from 1 to 200. For numbers that are multiples of 3, instead of the number, print "Fizz". For numbers that are multiples of 5, print "Buzz". For numbers that are multiples of both 3 and 5, print "FizzBuzz".

# %% [markdown]
# ## Answer:

# %%
# Answer:
